# %% [markdown]
# Question 1

# %%
import pandas as pd
data = {'BRA': [13.37, 13.30, 14.34, 15.07, 15.46, 15.98, 16.10],
'JPN': [33.43, 31.83, 33.71, 34.29, 35.60, 36.79, 37.39],
'USA': [48.30, 46.91, 48.31, 49.72, 51.41, 52.94, 54.60],
'Year': [2008, 2009, 2010, 2011, 2012, 2013, 2014]}
weo = pd.DataFrame(data)
weo
# Out:
#      BRA    JPN    USA  Year
# 0  13.37  33.43  48.30  2008
# 1  13.30  31.83  46.91  2009
# 2  14.34  33.71  48.31  2010
# 3  15.07  34.29  49.72  2011
# 4  15.46  35.60  51.41  2012
# 5  15.98  36.79  52.94  2013
# 6  16.10  37.39  54.60  2014

# %% [markdown]
# a. The import statement imports the open source library, "pandas" into the program and names it as "pd."
#
# b. The object of data is a dictionary.
#
# c. The last line has pd prior to the DataFrame function because DataFrame is a method in the pandas library. Since pandas is saved as pd, you have to put pd before DataFrame to call it.
#
# d. Weo is a 2-Dimensional Data Structure, known as a DataFrame in pandas. It can be seen similar to a multidimensional array.
#
# e. There are four columns and seven rows.
#
# f. The types of BRA, JPN, USA, and Year are strings. The columns (the contents under each variable) for BRA, JPN, and USA are floats while the column for Year is Integer. This means that a DataFrame can hold different types.
#
# g.
#
#     weo['Year']: Returns the year column as a Series
#     weo[['Year']]: Returns the year column as a DataFrame
#     weo[[3]]: Returns an error
# h.

# %%
weo['Year'] = weo['Year'].astype(float)

# %% [markdown]
# i. t = weo.tail(3): It is still a dataframe in Pandas. It looks like the last three lines of the original dataframe, weo.
#
# j.

# %%
b = weo.head(4)

# %% [markdown]
# k. weo['BRA'] is a Series in Pandas. The elements in the series are floats.
#
# l.

# %%
weo['Brazil_to_Japan_GDP'] = weo['BRA']/weo['JPN']

# %% [markdown]
# m.

# %%
weo = weo.drop('Brazil_to_Japan_GDP',1)

# %% [markdown]
# n. weo's row label: 0,1,2,3,4,5,6. weo's column labels: BRA, JPN, USA, YEAR

# %% [markdown]
# o.

# %%
weo = weo.set_index('Year')

# %% [markdown]
# p.

# %%
weo = weo.rename(columns={'BRA':'Brazil','JPN':'Japan','USA':'United States'})

# %% [markdown]
# q.

# %%
writer = pd.ExcelWriter('pandas_simple.xlsx', engine='xlsxwriter')
weo.to_excel(writer, sheet_name='Assignment 3')

# %% [markdown]
# r.
#
# To compute the mean for each one, I would use the method: weo.mean().

# %%
weo.mean()
# Out:
# Brazil           14.802857
# Japan            34.720000
# United States    50.312857
# dtype: float64

# %% [markdown]
# s.

# %%
weo.mean(1,0)
# Out:
# Year
# 2008.0    31.700000
# 2009.0    30.680000
# 2010.0    32.120000
# 2011.0    33.026667
# 2012.0    34.156667
# 2013.0    35.236667
# 2014.0    36.030000
# dtype: float64

# %% [markdown]
# t.

# %%
weo.plot()

# %% [markdown]
# u.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
weo = weo.rename(columns={'United States':'US'})
fig,ax = plt.subplots()
weo.plot(ax=ax)
weo.Brazil.plot(color='g')
weo.Japan.plot(color='r')
weo.US.plot(color='b')

# %% [markdown]
# v.

# %%
fig,ax = plt.subplots()
weo.plot(ax=ax,logy=True)

# %% [markdown]
# w.

# %%
fig,ax = plt.subplots()
weo['Brazil'].plot(ax=ax)

# %% [markdown]
# Question 2
#
# a.

# %%
import pandas as pd
import io
import requests
url="https://raw.githubusercontent.com/NYUDataBootcamp/Materials/master/Data/entry_poll_fall16.csv"
s=requests.get(url).content
ep = pd.read_csv(io.StringIO(s.decode('utf-8')))

# %% [markdown]
# b.

# %%
list(ep.columns.values)
# Out:
# ['TimeStamp',
#  'Why have you enrolled in this course?  ',
#  'What program are you enrolled in?',
#  'How much programming experience have you had?',
#  'How much experience with probability and statistics have you had?',
#  'What is your expected major or concentration? ',
#  'What career path most interests you? ',
#  'Do you use social media for information purposes?  Check all that apply.',
#  'What kinds of data most interest you?  List any that cross your mind.  ',
#  'If we have time -- and we may not -- what special topics would interest you?  Check all that apply.']

# %% [markdown]
# The output above lists the variables. Each variable asks a question regarding the responder's career. For each variable question there is a different set of answer choices. All categories are categorical and answers are qualitative rather than quantitative.
#
# c. The data types for all the variables are strings, as they are questions.
#
# d.

# %%
ep.columns = ['Time','Enrollment Reason','Program Enrolled','Programming Experience','Probability and Statistic Experience',
             'Expected Major','Career Path Interest','Social Media','Data Set Interests','Special Topics']

# %% [markdown]
# e.
#
# ep[list(ep)[1]].value_counts() lists the frequency for each response answer in the second column, which asks the reason for the enrollment in the class. The function does this by converting the variable responses into a list, taking the second element in that list, which is the enrollment reason, and subsequenting using pandas function of value counting to count each response type.
#
# Question 3
#
# a.

# %%
import pandas as pd
import io
import requests
url1 = 'https://raw.githubusercontent.com/fivethirtyeight/data/master/'
url2 = 'college-majors/recent-grads.csv'
url = url1 + url2
s=requests.get(url).content
df538 = pd.read_csv(io.StringIO(s.decode('utf-8')))
df538.shape
# Out:
# (173, 21)

# %% [markdown]
# There are 173 rows and 21 columns.

# %% [markdown]
# b.

# %%
pd.read_csv(io.StringIO(s.decode('utf-8')),nrows=10)
# Out:
#    Rank  Major_code                                      Major  Total    Men  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339   2057
# 1     2        2416             MINING AND MINERAL ENGINEERING    756    679
# 2     3        2415                  METALLURGICAL ENGINEERING    856    725
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258   1123
# 4     5        2405                       CHEMICAL ENGINEERING  32260  21239
# 5     6        2418                        NUCLEAR ENGINEERING   2573   2200
# 6     7        6202                          ACTUARIAL SCIENCE   3777   2110
# 7     8        5001                 ASTRONOMY AND ASTROPHYSICS   1792    832
# 8     9        2414                     MECHANICAL ENGINEERING  91227  80320
# 9    10        2408                     ELECTRICAL ENGINEERING  81527  65511
#
#    Women     Major_category  ShareWomen  Sample_size  Employed      ...        \
# ...

# %% [markdown]
# c.

# %%
variables = list(df538)
indexes = [2, 4, 15, 16, 17]
[variables[x] for x in indexes]
# Out:
# ['Major', 'Men', 'Median', 'P25th', 'P75th']

# %% [markdown]
# The output above lists the variable names for the requested indexes. However, the index for 2 actually gives the 3rd variable in the list. They represent the different categories for descriptions regarding careers in the population.
#
# d.

# %%
df538= df538.set_index('Major')

# %% [markdown]
# e.

# %%
df538.sort_values(by=['Total'])
# Out:
#                                                     Rank  Major_code  \
# Major
# MILITARY TECHNOLOGIES                                 74        3801
# MATHEMATICS AND COMPUTER SCIENCE                      53        4005
# SOIL SCIENCE                                         113        1106
# GEOLOGICAL AND GEOPHYSICAL ENGINEERING                34        2411
# MINING AND MINERAL ENGINEERING                         2        2416
# EDUCATIONAL ADMINISTRATION AND SUPERVISION           121        2301
# SCHOOL STUDENT COUNSELING                             56        2303
# METALLURGICAL ENGINEERING                              3        2415
# LIBRARY SCIENCE                                      173        3501
# COURT REPORTING                                       20        3201
# NAVAL ARCHITECTURE AND MARINE ENGINEERING              4        2417
# BOTANY                                                84        3602
# ...

# %% [markdown]
# f. To extract the ten majors with the greatest amount of workers, I would sort the dataframe from highest to lowest by total count in each major, create a list of the indexes based on this new list, and then return the first ten majors in the list.

# %%
df538 = df538.sort_values(by=['Total'],ascending=False)
a = list(df538.index)
[a[i] for i in range(10)]
# Out:
# ['PSYCHOLOGY',
#  'BUSINESS MANAGEMENT AND ADMINISTRATION',
#  'BIOLOGY',
#  'GENERAL BUSINESS',
#  'COMMUNICATIONS',
#  'NURSING',
#  'MARKETING AND MARKETING RESEARCH',
#  'ACCOUNTING',
#  'ENGLISH LANGUAGE AND LITERATURE',
#  'POLITICAL SCIENCE AND GOVERNMENT']

# %% [markdown]
# g.

# %%
import matplotlib.pyplot as plt
df538 = df538.sort_values(by=['Total'],ascending=False)
g = df538.head(10)
g_1 = g.sort_values(by=['Median'])
fig, ax = plt.subplots()
g_1['Median'].plot(kind='barh',ax=ax)

# %%
import matplotlib.pyplot as plt
df538 = df538.sort_values(by=['Total'],ascending=False)
g = df538.head(10)
g_2 = g.sort_values(by=['P25th'])
fig, ax = plt.subplots()
g_2['P25th'].plot(kind='barh',ax=ax)
